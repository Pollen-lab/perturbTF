# %% [markdown]
# # Individual assignment

# %% [markdown]
# Assigning individual based on metadata of 10X pooling and SNP genotyping from scRNA-seq data derived from Vireo

# %%
import numpy as np
import matplotlib.pyplot as plt
import vireoSNP
import os

# %% [markdown]
# ## 2D

# %%
directory='/wynton/scratch/jding/vireo'

# %%
f1 = '2D_L2'
f2 = '2D_L3'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (944307, 3, 3)
# Shape for Geno Prob in VCF2: (944307, 3, 3)
# n_variants in VCF1, VCF2 and matched: 944307, 958260, 657713
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor1' 'donor2' 'donor0']

# %%
f1 = '2D_L2'
f2 = '2D_L4'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (944307, 3, 3)
# Shape for Geno Prob in VCF2: (944307, 3, 3)
# n_variants in VCF1, VCF2 and matched: 944307, 937403, 681272
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor0' 'donor2' 'donor1']

# %%
f1 = '2D_L3'
f2 = '2D_L4'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (958260, 3, 3)
# Shape for Geno Prob in VCF2: (958260, 3, 3)
# n_variants in VCF1, VCF2 and matched: 958260, 937403, 655387
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor0' 'donor1' 'donor2']

# %% [markdown]
# 2D_L2:
# donor0:GW16#172-F
# donor1:GW18#140-M
# donor2:GW16#130-F
#
# 2D_L3:
# donor0:GW16#130-F
# donor1:GW18#151-F
# donor2:GW18#140-M
#
# 2D_L4:
# donor0:GW16#172-F
# donor1:GW18#151-F
# donor2:GW18#140-M

# %% [markdown]
# ## HM2D

# %%
directory='/wynton/scratch/jding/vireo-humanonly'

# %%
f1 = 'HM2D_L1'
f2 = 'HM2D_L3'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (406961, 3, 3)
# Shape for Geno Prob in VCF2: (406961, 3, 3)
# n_variants in VCF1, VCF2 and matched: 406961, 451337, 337871
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor2' 'donor1' 'donor0']

# %%
directory1 ='/wynton/scratch/jding/vireo-humanonly'
f1 = 'HM2D_L1'
directory2 ='/wynton/scratch/jding/vireo'
f2 = '2D_L4'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory1,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory2,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (406961, 3, 3)
# Shape for Geno Prob in VCF2: (406961, 3, 3)
# n_variants in VCF1, VCF2 and matched: 406961, 937403, 325871
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor2' 'donor0' 'donor1']

# %%
directory1 ='/wynton/scratch/jding/vireo-humanonly'
f1 = 'HM2D_L3'
directory2 ='/wynton/scratch/jding/vireo'
f2 = '2D_L4'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory1,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory2,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (451337, 3, 3)
# Shape for Geno Prob in VCF2: (451337, 3, 3)
# n_variants in VCF1, VCF2 and matched: 451337, 937403, 368794
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor1' 'donor0' 'donor2']

# %% [markdown]
# HM2D_L1:
# donor0:GW18#140-M
# donor1:GW16#172-F
# donor2:GW17#187-M
#
# HM2D_L3:
# donor0:GW18#183-M
# donor1:GW16#172-F
# donor2:GW18#140-M
#
# 2D_L4:
# donor0:GW16#172-F
# donor1:GW18#151-F
# donor2:GW18#140-M

# %% [markdown]
# ## HM2D_2nd

# %%
directory='/wynton/group/pollen/jding/brainchromatin/HM2D/vireo/'

# %%
f1 = 'HM2D_2nd_L1'
f2 = 'HM2D_2nd_L2'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (755418, 4, 3)
# Shape for Geno Prob in VCF2: (755418, 4, 3)
# n_variants in VCF1, VCF2 and matched: 755418, 807118, 654765
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor2' 'donor3' 'donor0' 'donor1']

# %%
f1 = 'HM2D_2nd_L1'
f2 = 'HM2D_L3'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (755418, 4, 3)
# Shape for Geno Prob in VCF2: (755418, 4, 3)
# n_variants in VCF1, VCF2 and matched: 755418, 451337, 236970
# aligned donors:
# ['donor0' 'donor2' 'donor3']
# ['donor1' 'donor2' 'donor0']

# %%
f1 = 'HM2D_2nd_L2'
f2 = 'HM2D_L3'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (807118, 4, 3)
# Shape for Geno Prob in VCF2: (807118, 4, 3)
# n_variants in VCF1, VCF2 and matched: 807118, 451337, 246352
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor2' 'donor0' 'donor1']

# %% [markdown]
# HM2D_2nd_L1:
# donor0:GW17#136-F
# donor1:GW19#153-F
# donor2:GW22#147-M
# donor3:GW18#183-M
#
# HM2D_2nd_L3:
# donor0:GW22#147-M
# donor1:GW18#183-M
# donor2:GW17#136-F
# donor3:GW19#153-F

# %% [markdown]
# ## HM2D_3rd

# %%
directory='/wynton/group/pollen/jding/brainchromatin/HM2D/vireo/'

# %%
f1 = 'HM2D_3rd_L1'
f2 = 'HM2D_3rd_L2'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (297947, 3, 3)
# Shape for Geno Prob in VCF2: (297947, 3, 3)
# n_variants in VCF1, VCF2 and matched: 297947, 333810, 199356
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor1' 'donor0' 'donor2']

# %% [markdown]
# HM2D_3rd_L1:
# donor0:GW21#143-F
# donor1:GW19#139-M
# donor2:GW16#161-F
#
# HM2D_3rd_L2:
# donor0:GW19#139-M
# donor1:GW21#154-F
# donor2:GW16#161-F

# %% [markdown]
# ## pip-seq

# %%
directory='/wynton/group/pollen/jding/brainchromatin/HM2D/vireo/'

# %%
f1 = 'LMO1'
f2 = 'HM2D_3rd_L2'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory1,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (64276, 4, 3)
# Shape for Geno Prob in VCF2: (64276, 4, 3)
# n_variants in VCF1, VCF2 and matched: 64276, 333810, 38324
# aligned donors:
# ['donor0' 'donor1' 'donor3']
# ['donor2' 'donor0' 'donor1']

# %%
f1 = 'HM2D_L1'
f2 = 'LMO1'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory1,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.savefig('/wynton/home/pollenlab/jding/BrainChromatin/HM2D.pdf')
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (406961, 3, 3)
# Shape for Geno Prob in VCF2: (406961, 3, 3)
# n_variants in VCF1, VCF2 and matched: 406961, 64276, 35882
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor1' 'donor0' 'donor2']

# %% [markdown]
# LMO1:
# donor0:GW16#196-M
# donor1:GW19#139-M
# donor2:GW17#187-M
# donor3:GW21#154-F

# %% [markdown]
# ## SlicePS

# %%
directory='/wynton/group/pollen/jding/brainchromatin/SlicePS/vireo'

# %%
f1 = 'SlicePS_L1'
f2 = 'SlicePS_L2'
res = vireoSNP.vcf.match_VCF_samples(os.path.join(directory,f1,'GT_donors.vireo.vcf.gz'),
                                     os.path.join(directory,f2,'GT_donors.vireo.vcf.gz'),
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (397255, 4, 3)
# Shape for Geno Prob in VCF2: (397255, 4, 3)
# n_variants in VCF1, VCF2 and matched: 397255, 343445, 283490
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor2' 'donor0' 'donor3' 'donor1']

# %% [markdown]
# SlicePS_L1:
# donor0:GW19A, 7406
# donor1:GW19B, 7550
# donor2:GW22#201, 10860
# donor3:GW20#200, 1265
#
# SlicePS_L2:
# donor0:GW19B, 10257
# donor1:GW20#200, 1229
# donor2:GW19A, 8995
# donor3:GW22#201, 5771
